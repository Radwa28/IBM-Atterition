# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
emp_df=pd.read_csv('C:\\Users\\Radwa\\Desktop\\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
emp_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
emp_df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
emp_df.shape
# Out:
# (1470, 35)

# %%
emp_df.columns=emp_df.columns.str.lower()

# %%
emp_df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager'],
#       dtype='object')

# %%
emp_df.isnull().sum()
# Out:
# age                         0
# attrition                   0
# businesstravel              0
# dailyrate                   0
# department                  0
# distancefromhome            0
# education                   0
# educationfield              0
# employeecount               0
# employeenumber              0
# environmentsatisfaction     0
# gender                      0
# hourlyrate                  0
# jobinvolvement              0
# joblevel                    0
# jobrole                     0
# jobsatisfaction             0
# maritalstatus               0
# monthlyincome               0
# monthlyrate                 0
# numcompaniesworked          0
# over18                      0
# overtime                    0
# percentsalaryhike           0
# performancerating           0
# relationshipsatisfaction    0
# standardhours               0
# stockoptionlevel            0
# totalworkingyears           0
# trainingtimeslastyear       0
# worklifebalance             0
# ...

# %%
#check null vaue with anthor way

# %%
emp_df.isnull().values.any()
# Out:
# False

# %%
#check the number that left and stayed from Attrition column

# %%
emp_df['attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: attrition, dtype: int64

# %%
emp_df.attrition=(emp_df.attrition=='yes').astype(int)

# %%
emp_df['attrition'].value_counts()
# Out:
# 0    1470
# Name: attrition, dtype: int64

# %%
#Visualization this Ratio of Attrition

# %%
sns.countplot(emp_df['attrition'])
# Out:
# C:\Users\Radwa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='attrition', ylabel='count'>

# %%
#drop some columns that aren't help us in EDA

# %%
emp_df.drop('over18',axis=1,inplace =True)
emp_df.drop('employeecount',axis=1,inplace =True)
emp_df.drop('employeenumber',axis=1,inplace =True)
emp_df.drop('standardhours',axis=1,inplace =True)

# %%
#to check that the columns already deleted
emp_df.corr()
# Out:
#                                age  attrition  dailyrate  distancefromhome  \
# age                       1.000000        NaN   0.010661         -0.001686
# attrition                      NaN        NaN        NaN               NaN
# dailyrate                 0.010661        NaN   1.000000         -0.004985
# distancefromhome         -0.001686        NaN  -0.004985          1.000000
# education                 0.208034        NaN  -0.016806          0.021042
# environmentsatisfaction   0.010146        NaN   0.018355         -0.016075
# hourlyrate                0.024287        NaN   0.023381          0.031131
# jobinvolvement            0.029820        NaN   0.046135          0.008783
# joblevel                  0.509604        NaN   0.002966          0.005303
# jobsatisfaction          -0.004892        NaN   0.030571         -0.003669
# monthlyincome             0.497855        NaN   0.007707         -0.017014
# ...

# %%
plt.figure(figsize=(15,17))
sns.heatmap(emp_df.corr(),annot=True,fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
#from this correlation the age related to all attributes and joblevel related to monthly income and hour rate

# %%
sns.distplot(emp_df['age'],bins=25)
# Out:
# C:\Users\Radwa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.pie(emp_df['age'],labels =emp_df['gender'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1f38ba4dbb0>,
# ...
#   ...],
#  [Text(1.099996902707321, 0.0026103705293420596, 'Female'),
#   Text(1.099968380481805, 0.00834038010135924, 'Male'),
#   Text(1.099913238211532, 0.013815513273932736, 'Male'),
#   Text(1.0998482360773785, 0.018271770507523797, 'Female'),
#   Text(1.0997781501751949, 0.02209118369908988, 'Male'),
#   Text(1.0996962985783583, 0.025846680503667795, 'Male'),
#   Text(1.0995449097093588, 0.031638450218654225, 'Female'),
#   Text(1.0993673429691453, 0.037302080544677346, 'Male'),
#   Text(1.0992120142106272, 0.04162868980662301, 'Male'),
#   Text(1.0990236326447829, 0.046336323637785004, 'Male'),
#   Text(1.0988239361348073, 0.05085230945797045, 'Male'),
#   Text(1.0986280254903347, 0.0549223233959436, 'Female'),
#   Text(1.0984306678918407, 0.05873727806669797, 'Male'),
#   Text(1.0982019147070252, 0.06286934494508437, 'Male'),
#   Text(1.0979692349592647, 0.06680987264594576, 'Male'),
# ...

# %%
#check affect of bussines travle on attration

# %%
sns.countplot(x='businesstravel',hue='attrition',data=emp_df)
# Out:
# <AxesSubplot:xlabel='businesstravel', ylabel='count'>

# %%
plt.pie(emp_df['attrition'],labels= emp_df['businesstravel'])
# Out:
# C:\Users\Radwa\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3052: RuntimeWarning: invalid value encountered in true_divide
#   x = x / sx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 plt.pie(emp_df['attrition'],labels= emp_df['businesstravel'])
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
# ...

# %%
#check affect distancefromhome on the attrition

# %%
sns.countplot(x='distancefromhome',hue='attrition',data=emp_df)
# Out:
# <AxesSubplot:xlabel='distancefromhome', ylabel='count'>

# %%
sns.distplot(emp_df['distancefromhome'],bins=25)
# Out:
# C:\Users\Radwa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='distancefromhome', ylabel='Density'>

# %%
plt.pie(emp_df['attrition'],labels=emp_df['distancefromhome'],shadow=True)
# Out:
# C:\Users\Radwa\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3052: RuntimeWarning: invalid value encountered in true_divide
#   x = x / sx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 plt.pie(emp_df['attrition'],labels=emp_df['distancefromhome'],shadow=True)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
# ...

# %%
sns.countplot(x='dailyrate',hue='attrition',data=emp_df)

# %%
plt.pie(emp_df['attrition'],labels=emp_df['dailyrate'],shadow=True)

# %%
#Check the bigest department

# %%
plt.figure(figsize=(20,15))
sns.distplot(emp_df['department'],bins=25)

# %%
plt.pie(emp_df['attrition'],labels=emp_df['department'],shadow=True)

# %%
emp_df['department'].value_counts()

# %%
#check precentage of employee that work over time

# %%
mylabels = ['yes','no']
myexplode = [0.2, 0, 0, 0]

plt.pie(emp_df['overtime'], labels = mylabels, explode = myexplode, shadow = True)

# %%
#divition data to ctgorical and numerical

# %%
numerical =list(emp_df.select_dtypes(include=['number']))
catgorical=list(emp_df.select_dtypes(include=['object']))

# %%
emp_df[numerical].nunique()
emp_df[catgorical].nunique()

# %%
plt.subplots(figsize=(20,15))
sns.countplot(x='age',hue='attrition',data=emp_df,palette='colorblind')

# %%
catgorical

# %%
emp_df[catgorical].describe()

# %%
for col in catgorical:
    plot =sns.countplot(x=col,hue='attrition',data=emp_df)
    plt.show()

# %%
#show affect of YearsWithCurrManager om attrition

# %%
sns.distplot(emp_df['yearswithcurrmanager'],bins=25)

# %%
sns.boxplot(emp_df['yearsatcompany'])

# %%
#show ost jobsroles in attrition

# %%
sns.countplot(x='jobrole',hue='attrition',data=emp_df)

# %%
plt.pie(emp_df['attrition'],labels=emp_df['jobrole'])

# %%
#see some features that affect on income

# %%
plt.figure(figsize=(20,15))
sns.palplot(x='jobrole',y='monthlyincome',hue='attrition',data=emp_df)

# %%
#let see role of education field on attrition

# %%
sns.countplot(x='educationfield',hue='attrition',data=emp_df)

# %%
plt.pie(emp_df['attrition'],labels=emp_df['educationfield'])

# %%
#let see affect of EnvironmentSatisfaction on Attrition

# %%
sns.countplot(x='environmentsatisfaction',hue='attrition',data=emp_df)

# %%
plt.pie(emp_df[attrition],lables=emp_df['environmentsatisfaction'])

# %%
#prepareing data for modeling

# %%
catgorical=list(df.select_dtypes(include=['object']))

# %%
catgorical

# %%
con_catgorical=pd.get_dummies(emp_df,columns=catgorical)

# %%
con_catgorical.head()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB

# %%
X_smote=con_catgorical

y_smote=con_catgorical.drop('attrition',axis=1)
y_smote = con_catgorical['attrition']
x_train, x_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size = 0.2, random_state =0)

# %% [markdown]
# logistic Regression

# %%
lr= LogisticRegression(random_state=0)
lr.fit(X_train, y_train)
over_fit=lr.score(X_test, y_test)   # test over fit

print(lr)

# %% [markdown]
# Dession Tree

# %%
dt = DecisionTreeClassifier(random_state=0)
dt.fit(x_train, y_train)
over_fit=dt.score(x_test, y_test)   # test over fit
print(over_fit)

# %% [markdown]
# Support Vector Machine

# %%
svm = SVC(random_state=0, C=1.5)
svm.fit(x_train, y_train)
accuracy = svm.score(x_test, y_test)
print(accuracy)

# %% [markdown]
# KNN

# %%
knn_al=KNeighborsClassifier(random_state=0)
knn_al.fit(x_train, y_train)
knn_accuracy = knn_model.score(x_test, y_test)
print(knn_al.score(x_train, y_train))    
print(knn_accuracy)

# %%
Naive bayes

# %%
model= GaussianNB()
model.fit(X_train, y_train)
model.score(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
